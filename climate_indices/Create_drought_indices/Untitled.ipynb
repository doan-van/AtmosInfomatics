# %%
import xarray as xr

# %%
ds = xr.open_dataset('spi_3month.nc')

# %%
ds['tp'][-1].plot()

# %%
(ds['tp'] > 2.)[200].plot()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 91, longitude: 180, time: 996)
# Coordinates:
#   * latitude   (latitude) float32 -90.0 -88.0 -86.0 -84.0 ... 86.0 88.0 90.0
#   * longitude  (longitude) float32 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#   * time       (time) datetime64[ns] 1940-01-01 1940-02-01 ... 2022-12-01
# Data variables:
#     tp         (time, latitude, longitude) float64 nan nan nan ... 0.4362 0.4362
