# %%
from tensorflow import keras

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.17.1'

# %%
keras.__version__
# Out:
# '3.6.0'

# %%
import numpy as np
import xarray as xr
import tensorflow as tf 
# all the layers used for U-net
from keras.layers import (Activation, BatchNormalization, Concatenate, Conv2D,
                                     Conv2DTranspose, Input, MaxPool2D)
from keras.models import Model
import keras.utils as ku
from keras.optimizers import Adam
import sys

# %%
dtrain0 = xr.open_dataset('data/nagoya_train.nc')
dval0 = xr.open_dataset('data/nagoya_val.nc')
dtest0 = xr.open_dataset('data/nagoya_test.nc')

# %%
# normalize data 
def datnorm(d): 
    return (d - d.mean()) / d.std()

# %%
# normalize data
dtrain, dval, dtest = datnorm(dtrain0), datnorm(dval0), datnorm(dtest0)
#dtrain, dval, dtest = dtrain0, dval0, dtest0

# %%
int_data = dtrain['lo'].values
X_train = np.expand_dims(int_data,3)
y_train = dtrain['hi'].values

# %%
X_val = np.expand_dims(dval['lo'].values,3)
y_val = dval['hi'].values

# %%
X_test = np.expand_dims(dtest['lo'].values,3)
y_test = dtest['hi'].values

# %%
print('Shape of X_train: ', X_train.shape)
print('Shape of y_train: ', y_train.shape)
print('Shape of X_validation: ', X_val.shape)
print('Shape of y_validation: ', y_val.shape)
print('Shape of X_test: ', X_test.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# Shape of X_train:  (255, 120, 104, 1)
# Shape of y_train:  (255, 120, 104)
# Shape of X_validation:  (66, 120, 104, 1)
# Shape of y_validation:  (66, 120, 104)
# Shape of X_test:  (44, 120, 104, 1)
# Shape of y_test:  (44, 120, 104)

# %% [markdown]
# ## BUILDING U-NET HERE

# %%
from keras.callbacks import LearningRateScheduler

def scheduler(epoch, lr):
    if epoch < 50:
        return lr
    else:
        return lr * 0.95  # Reduce learning rate by 5% after each epoch from 50 onward

lr_callback = LearningRateScheduler(scheduler)

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, Dropout
from keras.models import Model
from keras.optimizers import Adam
from keras.losses import MeanSquaredError
from keras.callbacks import EarlyStopping, LearningRateScheduler
import matplotlib.pyplot as plt

# Define the tiny U-Net model adapted for input_shape=(120, 104, 1)
def tiny_unet(input_shape=(120, 104, 1)):
    inputs = Input(shape=input_shape)
    
    # Downsampling layer 1
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Dropout(0.1)(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    
    # Downsampling layer 2
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Dropout(0.1)(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    
    # Bottleneck
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    
    # Upsampling layer 1
    up2 = UpSampling2D((2, 2))(conv3)
    concat2 = Concatenate()([up2, conv2])
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(concat2)
    conv4 = Dropout(0.1)(conv4)
    
    # Upsampling layer 2
    up1 = UpSampling2D((2, 2))(conv4)
    concat1 = Concatenate()([up1, conv1])
    conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(concat1)
    conv5 = Dropout(0.1)(conv5)
    
    # Output layer for continuous values (linear activation)
    outputs = Conv2D(1, (1, 1), activation=None)(conv5)
    
    return Model(inputs, outputs)

# Instantiate the tiny U-Net model with the new input shape
unet_model = tiny_unet(input_shape=(120, 104, 1))

# Compile the model with MSE loss and Adam optimizer
unet_model.compile(optimizer=Adam(learning_rate=0.00005), 
                   loss=MeanSquaredError(), 
                   metrics=['mae'])

# Define a learning rate schedule (exponential decay)
def lr_schedule(epoch, lr):
    decay_rate = 0.95  # Decay factor
    decay_epoch = 10   # Apply decay every 10 epochs
    if epoch % decay_epoch == 0 and epoch != 0:
        return lr * decay_rate
    return lr

# Define callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# Train the model with the learning rate scheduler
history = unet_model.fit(
    x=X_train, 
    y=y_train, 
    validation_data=(X_val, y_val),
    epochs=300,
    batch_size=16,
    callbacks=[early_stop, lr_scheduler]
)

# Save the model
unet_model.save('nagoya_tiny_unet_120x104.keras')

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Curves')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 1/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 442ms/step - loss: 0.8955 - mae: 0.8047 - val_loss: 0.4821 - val_mae: 0.5888 - learning_rate: 5.0000e-05
#
# Epoch 2: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 2/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 432ms/step - loss: 0.3634 - mae: 0.4977 - val_loss: 0.1486 - val_mae: 0.2968 - learning_rate: 5.0000e-05
#
# Epoch 3: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 3/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 489ms/step - loss: 0.1013 - mae: 0.2342 - val_loss: 0.0561 - val_mae: 0.1723 - learning_rate: 5.0000e-05
#
# Epoch 4: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 4/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 499ms/step - loss: 0.0814 - mae: 0.2174 - val_loss: 0.0750 - val_mae: 0.2118 - learning_rate: 5.0000e-05
#
# Epoch 5: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 5/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 463ms/step - loss: 0.0763 - mae: 0.2060 - val_loss: 0.0723 - val_mae: 0.2074 - learning_rate: 5.0000e-05
#
# Epoch 6: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 6/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 470ms/step - loss: 0.0695 - mae: 0.1983 - val_loss: 0.0622 - val_mae: 0.1915 - learning_rate: 5.0000e-05
#
# Epoch 7: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 7/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 10s 610ms/step - loss: 0.0667 - mae: 0.1959 - val_loss: 0.0632 - val_mae: 0.1948 - learning_rate: 5.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 8/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 9s 541ms/step - loss: 0.0653 - mae: 0.1937 - val_loss: 0.0605 - val_mae: 0.1933 - learning_rate: 5.0000e-05
#
# Epoch 9: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 9/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 472ms/step - loss: 0.0652 - mae: 0.1938 - val_loss: 0.0642 - val_mae: 0.2017 - learning_rate: 5.0000e-05
#
# Epoch 10: LearningRateScheduler setting learning rate to 4.999999873689376e-05.
# Epoch 10/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 466ms/step - loss: 0.0631 - mae: 0.1917 - val_loss: 0.0660 - val_mae: 0.2042 - learning_rate: 5.0000e-05
#
# Epoch 11: LearningRateScheduler setting learning rate to 4.749999880004907e-05.
# Epoch 11/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 452ms/step - loss: 0.0588 - mae: 0.1845 - val_loss: 0.0574 - val_mae: 0.1922 - learning_rate: 4.7500e-05
#
# Epoch 12: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 12/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 461ms/step - loss: 0.0569 - mae: 0.1838 - val_loss: 0.0615 - val_mae: 0.1982 - learning_rate: 4.7500e-05
#
# Epoch 13: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 13/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 468ms/step - loss: 0.0547 - mae: 0.1798 - val_loss: 0.0504 - val_mae: 0.1789 - learning_rate: 4.7500e-05
#
# Epoch 14: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 14/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 464ms/step - loss: 0.0565 - mae: 0.1839 - val_loss: 0.0508 - val_mae: 0.1784 - learning_rate: 4.7500e-05
#
# Epoch 15: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 15/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 483ms/step - loss: 0.0528 - mae: 0.1779 - val_loss: 0.0509 - val_mae: 0.1772 - learning_rate: 4.7500e-05
#
# Epoch 16: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 16/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 460ms/step - loss: 0.0540 - mae: 0.1784 - val_loss: 0.0512 - val_mae: 0.1809 - learning_rate: 4.7500e-05
#
# Epoch 17: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 17/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 444ms/step - loss: 0.0517 - mae: 0.1760 - val_loss: 0.0524 - val_mae: 0.1850 - learning_rate: 4.7500e-05
#
# Epoch 18: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 18/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 452ms/step - loss: 0.0505 - mae: 0.1745 - val_loss: 0.0506 - val_mae: 0.1822 - learning_rate: 4.7500e-05
#
# Epoch 19: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 19/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 443ms/step - loss: 0.0535 - mae: 0.1791 - val_loss: 0.0555 - val_mae: 0.1898 - learning_rate: 4.7500e-05
#
# Epoch 20: LearningRateScheduler setting learning rate to 4.749999789055437e-05.
# Epoch 20/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 443ms/step - loss: 0.0512 - mae: 0.1745 - val_loss: 0.0529 - val_mae: 0.1847 - learning_rate: 4.7500e-05
#
# Epoch 21: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 21/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 474ms/step - loss: 0.0517 - mae: 0.1743 - val_loss: 0.0496 - val_mae: 0.1802 - learning_rate: 4.5125e-05
#
# Epoch 22: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 22/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 450ms/step - loss: 0.0502 - mae: 0.1736 - val_loss: 0.0492 - val_mae: 0.1757 - learning_rate: 4.5125e-05
#
# Epoch 23: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 23/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 465ms/step - loss: 0.0489 - mae: 0.1707 - val_loss: 0.0478 - val_mae: 0.1754 - learning_rate: 4.5125e-05
#
# Epoch 24: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 24/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 453ms/step - loss: 0.0508 - mae: 0.1751 - val_loss: 0.0519 - val_mae: 0.1821 - learning_rate: 4.5125e-05
#
# Epoch 25: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 25/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 444ms/step - loss: 0.0514 - mae: 0.1749 - val_loss: 0.0501 - val_mae: 0.1809 - learning_rate: 4.5125e-05
#
# Epoch 26: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 26/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 441ms/step - loss: 0.0488 - mae: 0.1704 - val_loss: 0.0479 - val_mae: 0.1771 - learning_rate: 4.5125e-05
#
# Epoch 27: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 27/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 448ms/step - loss: 0.0477 - mae: 0.1681 - val_loss: 0.0446 - val_mae: 0.1704 - learning_rate: 4.5125e-05
#
# Epoch 28: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 28/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 454ms/step - loss: 0.0501 - mae: 0.1746 - val_loss: 0.0502 - val_mae: 0.1784 - learning_rate: 4.5125e-05
#
# Epoch 29: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 29/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 446ms/step - loss: 0.0474 - mae: 0.1674 - val_loss: 0.0419 - val_mae: 0.1627 - learning_rate: 4.5125e-05
#
# Epoch 30: LearningRateScheduler setting learning rate to 4.512499799602665e-05.
# Epoch 30/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 444ms/step - loss: 0.0479 - mae: 0.1702 - val_loss: 0.0473 - val_mae: 0.1733 - learning_rate: 4.5125e-05
#
# Epoch 31: LearningRateScheduler setting learning rate to 4.286874809622532e-05.
# Epoch 31/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 447ms/step - loss: 0.0464 - mae: 0.1675 - val_loss: 0.0453 - val_mae: 0.1683 - learning_rate: 4.2869e-05
#
# Epoch 32: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 32/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 446ms/step - loss: 0.0481 - mae: 0.1691 - val_loss: 0.0476 - val_mae: 0.1753 - learning_rate: 4.2869e-05
#
# Epoch 33: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 33/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 472ms/step - loss: 0.0487 - mae: 0.1713 - val_loss: 0.0488 - val_mae: 0.1779 - learning_rate: 4.2869e-05
#
# Epoch 34: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 34/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.0470 - mae: 0.1672 - val_loss: 0.0461 - val_mae: 0.1708 - learning_rate: 4.2869e-05
#
# Epoch 35: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 35/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 443ms/step - loss: 0.0459 - mae: 0.1659 - val_loss: 0.0434 - val_mae: 0.1662 - learning_rate: 4.2869e-05
#
# Epoch 36: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 36/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 444ms/step - loss: 0.0474 - mae: 0.1686 - val_loss: 0.0481 - val_mae: 0.1728 - learning_rate: 4.2869e-05
#
# Epoch 37: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 37/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 452ms/step - loss: 0.0479 - mae: 0.1686 - val_loss: 0.0432 - val_mae: 0.1656 - learning_rate: 4.2869e-05
#
# Epoch 38: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 38/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 446ms/step - loss: 0.0482 - mae: 0.1697 - val_loss: 0.0480 - val_mae: 0.1762 - learning_rate: 4.2869e-05
#
# Epoch 39: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 39/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 444ms/step - loss: 0.0474 - mae: 0.1681 - val_loss: 0.0428 - val_mae: 0.1649 - learning_rate: 4.2869e-05
#
# Epoch 40: LearningRateScheduler setting learning rate to 4.286874900572002e-05.
# Epoch 40/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 443ms/step - loss: 0.0458 - mae: 0.1652 - val_loss: 0.0446 - val_mae: 0.1685 - learning_rate: 4.2869e-05
#
# Epoch 41: LearningRateScheduler setting learning rate to 4.072531155543402e-05.
# Epoch 41/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 469ms/step - loss: 0.0465 - mae: 0.1671 - val_loss: 0.0480 - val_mae: 0.1745 - learning_rate: 4.0725e-05
#
# Epoch 42: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 42/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.0468 - mae: 0.1666 - val_loss: 0.0454 - val_mae: 0.1700 - learning_rate: 4.0725e-05
#
# Epoch 43: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 43/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.0472 - mae: 0.1684 - val_loss: 0.0436 - val_mae: 0.1682 - learning_rate: 4.0725e-05
#
# Epoch 44: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 44/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 450ms/step - loss: 0.0477 - mae: 0.1702 - val_loss: 0.0475 - val_mae: 0.1749 - learning_rate: 4.0725e-05
#
# Epoch 45: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 45/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.0465 - mae: 0.1666 - val_loss: 0.0437 - val_mae: 0.1663 - learning_rate: 4.0725e-05
#
# Epoch 46: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 46/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 444ms/step - loss: 0.0477 - mae: 0.1694 - val_loss: 0.0430 - val_mae: 0.1644 - learning_rate: 4.0725e-05
#
# Epoch 47: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 47/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 447ms/step - loss: 0.0443 - mae: 0.1627 - val_loss: 0.0393 - val_mae: 0.1579 - learning_rate: 4.0725e-05
#
# Epoch 48: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 48/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 453ms/step - loss: 0.0479 - mae: 0.1702 - val_loss: 0.0509 - val_mae: 0.1784 - learning_rate: 4.0725e-05
#
# Epoch 49: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 49/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 449ms/step - loss: 0.0459 - mae: 0.1649 - val_loss: 0.0408 - val_mae: 0.1597 - learning_rate: 4.0725e-05
#
# Epoch 50: LearningRateScheduler setting learning rate to 4.0725310100242496e-05.
# Epoch 50/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 448ms/step - loss: 0.0448 - mae: 0.1642 - val_loss: 0.0427 - val_mae: 0.1632 - learning_rate: 4.0725e-05
#
# Epoch 51: LearningRateScheduler setting learning rate to 3.868904459523037e-05.
# Epoch 51/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 455ms/step - loss: 0.0456 - mae: 0.1655 - val_loss: 0.0432 - val_mae: 0.1629 - learning_rate: 3.8689e-05
#
# Epoch 52: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 52/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 454ms/step - loss: 0.0444 - mae: 0.1619 - val_loss: 0.0414 - val_mae: 0.1609 - learning_rate: 3.8689e-05
#
# Epoch 53: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 53/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 448ms/step - loss: 0.0446 - mae: 0.1629 - val_loss: 0.0431 - val_mae: 0.1654 - learning_rate: 3.8689e-05
#
# Epoch 54: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 54/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 458ms/step - loss: 0.0461 - mae: 0.1665 - val_loss: 0.0498 - val_mae: 0.1785 - learning_rate: 3.8689e-05
#
# Epoch 55: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 55/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 445ms/step - loss: 0.0481 - mae: 0.1696 - val_loss: 0.0459 - val_mae: 0.1733 - learning_rate: 3.8689e-05
#
# Epoch 56: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 56/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 454ms/step - loss: 0.0463 - mae: 0.1660 - val_loss: 0.0438 - val_mae: 0.1682 - learning_rate: 3.8689e-05
#
# Epoch 57: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 57/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 454ms/step - loss: 0.0451 - mae: 0.1654 - val_loss: 0.0438 - val_mae: 0.1680 - learning_rate: 3.8689e-05
#
# Epoch 58: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 58/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 461ms/step - loss: 0.0460 - mae: 0.1664 - val_loss: 0.0456 - val_mae: 0.1703 - learning_rate: 3.8689e-05
#
# Epoch 59: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 59/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 448ms/step - loss: 0.0450 - mae: 0.1640 - val_loss: 0.0416 - val_mae: 0.1622 - learning_rate: 3.8689e-05
#
# Epoch 60: LearningRateScheduler setting learning rate to 3.8689046050421894e-05.
# Epoch 60/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 456ms/step - loss: 0.0454 - mae: 0.1645 - val_loss: 0.0462 - val_mae: 0.1723 - learning_rate: 3.8689e-05
#
# Epoch 61: LearningRateScheduler setting learning rate to 3.6754593747900795e-05.
# Epoch 61/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 462ms/step - loss: 0.0447 - mae: 0.1637 - val_loss: 0.0429 - val_mae: 0.1655 - learning_rate: 3.6755e-05
#
# Epoch 62: LearningRateScheduler setting learning rate to 3.675459447549656e-05.
# Epoch 62/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 478ms/step - loss: 0.0444 - mae: 0.1629 - val_loss: 0.0437 - val_mae: 0.1666 - learning_rate: 3.6755e-05
#
# Epoch 63: LearningRateScheduler setting learning rate to 3.675459447549656e-05.
# Epoch 63/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 450ms/step - loss: 0.0449 - mae: 0.1634 - val_loss: 0.0423 - val_mae: 0.1637 - learning_rate: 3.6755e-05
#
# Epoch 64: LearningRateScheduler setting learning rate to 3.675459447549656e-05.
# Epoch 64/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 454ms/step - loss: 0.0440 - mae: 0.1629 - val_loss: 0.0422 - val_mae: 0.1633 - learning_rate: 3.6755e-05
#
# Epoch 65: LearningRateScheduler setting learning rate to 3.675459447549656e-05.
# Epoch 65/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 459ms/step - loss: 0.0454 - mae: 0.1653 - val_loss: 0.0430 - val_mae: 0.1623 - learning_rate: 3.6755e-05
#
# Epoch 66: LearningRateScheduler setting learning rate to 3.675459447549656e-05.
# Epoch 66/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 457ms/step - loss: 0.0462 - mae: 0.1657 - val_loss: 0.0397 - val_mae: 0.1555 - learning_rate: 3.6755e-05
#
# Epoch 67: LearningRateScheduler setting learning rate to 3.675459447549656e-05.
# Epoch 67/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 7s 450ms/step - loss: 0.0470 - mae: 0.1661 - val_loss: 0.0399 - val_mae: 0.1566 - learning_rate: 3.6755e-05

# %%
unet_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_21      │ (None, 24, 32, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_206 (Conv2D) │ (None, 24, 32, 8) │         80 │ input_layer_21[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_58    │ (None, 12, 16, 8) │          0 │ conv2d_206[0][0]  │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_207 (Conv2D) │ (None, 12, 16,    │      1,168 │ max_pooling2d_58… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_59    │ (None, 6, 8, 16)  │          0 │ conv2d_207[0][0]  │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_208 (Conv2D) │ (None, 6, 8, 32)  │      4,640 │ max_pooling2d_59… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_10    │ (None, 12, 16,    │          0 │ conv2d_208[0][0]  │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_58      │ (None, 12, 16,    │          0 │ up_sampling2d_10… │
# │ (Concatenate)       │ 48)               │            │ conv2d_207[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_209 (Conv2D) │ (None, 12, 16,    │      6,928 │ concatenate_58[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_11    │ (None, 24, 32,    │          0 │ conv2d_209[0][0]  │
# │ (UpSampling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_59      │ (None, 24, 32,    │          0 │ up_sampling2d_11… │
# │ (Concatenate)       │ 24)               │            │ conv2d_206[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_210 (Conv2D) │ (None, 24, 32, 8) │      1,736 │ concatenate_59[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_211 (Conv2D) │ (None, 24, 32, 1) │          9 │ conv2d_210[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 43,685 (170.65 KB)
#  Trainable params: 14,561 (56.88 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 29,124 (113.77 KB)

# %%
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Concatenate, Dropout, BatchNormalization
from keras.models import Model
from keras.optimizers import Adam
from keras.losses import Huber
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# Define an enhanced U-Net model with increased capacity, batch normalization, and dropout
def enhanced_unet(input_shape=(120, 104, 1)):
    inputs = Input(shape=input_shape)
    
    # Downsampling layer 1
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer='l2')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Dropout(0.2)(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    
    # Downsampling layer 2
    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer='l2')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Dropout(0.2)(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    
    # Additional downsampling layer 3
    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer='l2')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Dropout(0.2)(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    
    # Bottleneck
    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same', kernel_regularizer='l2')(pool3)
    conv4 = BatchNormalization()(conv4)
    
    # Upsampling layer 1
    up3 = UpSampling2D((2, 2))(conv4)
    concat3 = Concatenate()([up3, conv3])
    conv5 = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer='l2')(concat3)
    conv5 = BatchNormalization()(conv5)
    conv5 = Dropout(0.2)(conv5)
    
    # Upsampling layer 2
    up2 = UpSampling2D((2, 2))(conv5)
    concat2 = Concatenate()([up2, conv2])
    conv6 = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer='l2')(concat2)
    conv6 = BatchNormalization()(conv6)
    conv6 = Dropout(0.2)(conv6)
    
    # Upsampling layer 3
    up1 = UpSampling2D((2, 2))(conv6)
    concat1 = Concatenate()([up1, conv1])
    conv7 = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer='l2')(concat1)
    conv7 = BatchNormalization()(conv7)
    conv7 = Dropout(0.2)(conv7)
    
    # Output layer for continuous values (linear activation)
    outputs = Conv2D(1, (1, 1), activation=None)(conv7)
    
    return Model(inputs, outputs)

# Instantiate the model with the updated input shape
unet_model = enhanced_unet(input_shape=(120, 104, 1))

# Compile the model with Huber loss and a lower learning rate
unet_model.compile(optimizer=Adam(learning_rate=1e-5), 
                   loss=Huber(delta=1.0), 
                   metrics=['mae'])

# Define callbacks: early stopping and adaptive learning rate scheduler
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1)

# Train the model
history = unet_model.fit(
    x=X_train, 
    y=y_train, 
    validation_data=(X_val, y_val),
    epochs=300,
    batch_size=16,
    callbacks=[early_stop, reduce_lr]
)

# Save the model
unet_model.save('enhanced_unet_120x104.keras')

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Curves')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - loss: 13.5028 - mae: 1.2028 - val_loss: 13.1502 - val_mae: 0.8900 - learning_rate: 1.0000e-05
# Epoch 2/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 13.2648 - mae: 1.0022 - val_loss: 13.0966 - val_mae: 0.9012 - learning_rate: 1.0000e-05
# Epoch 3/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 13.1218 - mae: 0.9157 - val_loss: 13.0181 - val_mae: 0.8923 - learning_rate: 1.0000e-05
# Epoch 4/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.9713 - mae: 0.8255 - val_loss: 12.9409 - val_mae: 0.8940 - learning_rate: 1.0000e-05
# Epoch 5/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - loss: 12.8511 - mae: 0.7784 - val_loss: 12.8526 - val_mae: 0.8885 - learning_rate: 1.0000e-05
# Epoch 6/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.7488 - mae: 0.7574 - val_loss: 12.7395 - val_mae: 0.8588 - learning_rate: 1.0000e-05
# Epoch 7/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.6387 - mae: 0.7323 - val_loss: 12.6035 - val_mae: 0.8048 - learning_rate: 1.0000e-05
# Epoch 8/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.5282 - mae: 0.7110 - val_loss: 12.4866 - val_mae: 0.7772 - learning_rate: 1.0000e-05
# Epoch 9/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.4357 - mae: 0.7146 - val_loss: 12.3601 - val_mae: 0.7414 - learning_rate: 1.0000e-05
# Epoch 10/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.2960 - mae: 0.6597 - val_loss: 12.2325 - val_mae: 0.7069 - learning_rate: 1.0000e-05
# Epoch 11/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.2030 - mae: 0.6676 - val_loss: 12.1006 - val_mae: 0.6699 - learning_rate: 1.0000e-05
# Epoch 12/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 12.0952 - mae: 0.6584 - val_loss: 11.9714 - val_mae: 0.6367 - learning_rate: 1.0000e-05
# Epoch 13/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.9785 - mae: 0.6378 - val_loss: 11.8558 - val_mae: 0.6206 - learning_rate: 1.0000e-05
# Epoch 14/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.8794 - mae: 0.6442 - val_loss: 11.7285 - val_mae: 0.5902 - learning_rate: 1.0000e-05
# Epoch 15/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.7840 - mae: 0.6529 - val_loss: 11.6075 - val_mae: 0.5681 - learning_rate: 1.0000e-05
# Epoch 16/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.6586 - mae: 0.6268 - val_loss: 11.4746 - val_mae: 0.5264 - learning_rate: 1.0000e-05
# Epoch 17/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.5349 - mae: 0.5999 - val_loss: 11.3694 - val_mae: 0.5281 - learning_rate: 1.0000e-05
# Epoch 18/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.4517 - mae: 0.6264 - val_loss: 11.2446 - val_mae: 0.4977 - learning_rate: 1.0000e-05
# Epoch 19/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - loss: 11.3448 - mae: 0.6251 - val_loss: 11.1093 - val_mae: 0.4508 - learning_rate: 1.0000e-05
# Epoch 20/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.2112 - mae: 0.5885 - val_loss: 11.0003 - val_mae: 0.4421 - learning_rate: 1.0000e-05
# Epoch 21/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 11.1087 - mae: 0.5915 - val_loss: 10.8832 - val_mae: 0.4196 - learning_rate: 1.0000e-05
# Epoch 22/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 11.0027 - mae: 0.5912 - val_loss: 10.7713 - val_mae: 0.4078 - learning_rate: 1.0000e-05
# Epoch 23/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 10.9630 - mae: 0.6816 - val_loss: 10.6582 - val_mae: 0.3897 - learning_rate: 1.0000e-05
# Epoch 24/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 10.7990 - mae: 0.6005 - val_loss: 10.5385 - val_mae: 0.3575 - learning_rate: 1.0000e-05
# Epoch 25/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 10.6846 - mae: 0.5873 - val_loss: 10.4283 - val_mae: 0.3461 - learning_rate: 1.0000e-05
# Epoch 26/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 10.5698 - mae: 0.5722 - val_loss: 10.3205 - val_mae: 0.3382 - learning_rate: 1.0000e-05
# Epoch 27/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 10.4582 - mae: 0.5639 - val_loss: 10.2036 - val_mae: 0.3080 - learning_rate: 1.0000e-05
# Epoch 28/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 10.3663 - mae: 0.5807 - val_loss: 10.1020 - val_mae: 0.3108 - learning_rate: 1.0000e-05
# Epoch 29/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 300s 20s/step - loss: 10.2587 - mae: 0.5764 - val_loss: 9.9933 - val_mae: 0.2955 - learning_rate: 1.0000e-05
# Epoch 30/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1011s 67s/step - loss: 10.1501 - mae: 0.5678 - val_loss: 9.8881 - val_mae: 0.2903 - learning_rate: 1.0000e-05
# Epoch 31/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 577s 38s/step - loss: 10.0698 - mae: 0.5998 - val_loss: 9.7875 - val_mae: 0.2916 - learning_rate: 1.0000e-05
# Epoch 32/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 9.9335 - mae: 0.5522 - val_loss: 9.6730 - val_mae: 0.2566 - learning_rate: 1.0000e-05
# Epoch 33/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 9.8238 - mae: 0.5387 - val_loss: 9.5745 - val_mae: 0.2657 - learning_rate: 1.0000e-05
# Epoch 34/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 9.7264 - mae: 0.5440 - val_loss: 9.4718 - val_mae: 0.2591 - learning_rate: 1.0000e-05
# Epoch 35/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - loss: 9.6307 - mae: 0.5531 - val_loss: 9.3731 - val_mae: 0.2658 - learning_rate: 1.0000e-05
# Epoch 36/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 9.5276 - mae: 0.5473 - val_loss: 9.2703 - val_mae: 0.2560 - learning_rate: 1.0000e-05
# Epoch 37/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 9.4153 - mae: 0.5275 - val_loss: 9.1696 - val_mae: 0.2500 - learning_rate: 1.0000e-05
# Epoch 38/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - loss: 9.3141 - mae: 0.5254 - val_loss: 9.0741 - val_mae: 0.2548 - learning_rate: 1.0000e-05
# Epoch 39/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 9.2266 - mae: 0.5437 - val_loss: 8.9747 - val_mae: 0.2512 - learning_rate: 1.0000e-05
# Epoch 40/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 9.1345 - mae: 0.5491 - val_loss: 8.8803 - val_mae: 0.2577 - learning_rate: 1.0000e-05
# Epoch 41/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 9.0396 - mae: 0.5541 - val_loss: 8.7838 - val_mae: 0.2598 - learning_rate: 1.0000e-05
# Epoch 42/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 8.9380 - mae: 0.5458 - val_loss: 8.6866 - val_mae: 0.2558 - learning_rate: 1.0000e-05
# Epoch 43/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 8.8614 - mae: 0.5761 - val_loss: 8.5903 - val_mae: 0.2517 - learning_rate: 1.0000e-05
# Epoch 44/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 8.7231 - mae: 0.5075 - val_loss: 8.4928 - val_mae: 0.2425 - learning_rate: 1.0000e-05
# Epoch 45/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 8.6485 - mae: 0.5382 - val_loss: 8.3980 - val_mae: 0.2378 - learning_rate: 1.0000e-05
# Epoch 46/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 8.5500 - mae: 0.5267 - val_loss: 8.3033 - val_mae: 0.2350 - learning_rate: 1.0000e-05
# Epoch 47/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 8.4555 - mae: 0.5250 - val_loss: 8.2121 - val_mae: 0.2349 - learning_rate: 1.0000e-05
# Epoch 48/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 8.3491 - mae: 0.5015 - val_loss: 8.1211 - val_mae: 0.2349 - learning_rate: 1.0000e-05
# Epoch 49/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 8.2582 - mae: 0.5030 - val_loss: 8.0297 - val_mae: 0.2358 - learning_rate: 1.0000e-05
# Epoch 50/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 8.1694 - mae: 0.5057 - val_loss: 7.9422 - val_mae: 0.2391 - learning_rate: 1.0000e-05
# Epoch 51/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 8.0831 - mae: 0.5109 - val_loss: 7.8532 - val_mae: 0.2387 - learning_rate: 1.0000e-05
# Epoch 52/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - loss: 7.9876 - mae: 0.5022 - val_loss: 7.7628 - val_mae: 0.2391 - learning_rate: 1.0000e-05
# Epoch 53/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 7.9119 - mae: 0.5222 - val_loss: 7.6755 - val_mae: 0.2384 - learning_rate: 1.0000e-05
# Epoch 54/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 7.8058 - mae: 0.4913 - val_loss: 7.5866 - val_mae: 0.2311 - learning_rate: 1.0000e-05
# Epoch 55/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 7.7336 - mae: 0.5156 - val_loss: 7.5030 - val_mae: 0.2377 - learning_rate: 1.0000e-05
# Epoch 56/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 7.6398 - mae: 0.5015 - val_loss: 7.4160 - val_mae: 0.2339 - learning_rate: 1.0000e-05
# Epoch 57/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 7.5541 - mae: 0.5011 - val_loss: 7.3308 - val_mae: 0.2305 - learning_rate: 1.0000e-05
# Epoch 58/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - loss: 7.4853 - mae: 0.5295 - val_loss: 7.2466 - val_mae: 0.2299 - learning_rate: 1.0000e-05
# Epoch 59/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - loss: 7.3789 - mae: 0.4864 - val_loss: 7.1638 - val_mae: 0.2308 - learning_rate: 1.0000e-05
# Epoch 60/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 7.3181 - mae: 0.5222 - val_loss: 7.0802 - val_mae: 0.2299 - learning_rate: 1.0000e-05
# Epoch 61/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - loss: 7.2114 - mae: 0.4840 - val_loss: 7.0017 - val_mae: 0.2340 - learning_rate: 1.0000e-05
# Epoch 62/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - loss: 7.1376 - mae: 0.4963 - val_loss: 6.9199 - val_mae: 0.2316 - learning_rate: 1.0000e-05
# Epoch 63/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - loss: 7.0723 - mae: 0.5236 - val_loss: 6.8399 - val_mae: 0.2333 - learning_rate: 1.0000e-05
# Epoch 64/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 6.9569 - mae: 0.4630 - val_loss: 6.7575 - val_mae: 0.2260 - learning_rate: 1.0000e-05
# Epoch 65/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 6.8854 - mae: 0.4720 - val_loss: 6.6776 - val_mae: 0.2270 - learning_rate: 1.0000e-05
# Epoch 66/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - loss: 6.8073 - mae: 0.4769 - val_loss: 6.6022 - val_mae: 0.2261 - learning_rate: 1.0000e-05
# Epoch 67/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - loss: 6.7367 - mae: 0.4881 - val_loss: 6.5214 - val_mae: 0.2194 - learning_rate: 1.0000e-05
# Epoch 68/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - loss: 6.6370 - mae: 0.4474 - val_loss: 6.4489 - val_mae: 0.2251 - learning_rate: 1.0000e-05
# Epoch 69/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 6.5680 - mae: 0.4594 - val_loss: 6.3705 - val_mae: 0.2205 - learning_rate: 1.0000e-05
# Epoch 70/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 6.4963 - mae: 0.4633 - val_loss: 6.2967 - val_mae: 0.2202 - learning_rate: 1.0000e-05
# Epoch 71/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - loss: 6.4186 - mae: 0.4589 - val_loss: 6.2252 - val_mae: 0.2297 - learning_rate: 1.0000e-05
# Epoch 72/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 50s 3s/step - loss: 6.3481 - mae: 0.4662 - val_loss: 6.1481 - val_mae: 0.2131 - learning_rate: 1.0000e-05
# Epoch 73/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - loss: 6.2545 - mae: 0.4264 - val_loss: 6.0756 - val_mae: 0.2139 - learning_rate: 1.0000e-05
# Epoch 74/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - loss: 6.2117 - mae: 0.4797 - val_loss: 6.0073 - val_mae: 0.2194 - learning_rate: 1.0000e-05
# Epoch 75/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 6.1141 - mae: 0.4333 - val_loss: 5.9330 - val_mae: 0.2146 - learning_rate: 1.0000e-05
# Epoch 76/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - loss: 6.0963 - mae: 0.5225 - val_loss: 5.8660 - val_mae: 0.2212 - learning_rate: 1.0000e-05
# Epoch 77/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - loss: 5.9845 - mae: 0.4515 - val_loss: 5.7940 - val_mae: 0.2111 - learning_rate: 1.0000e-05
# Epoch 78/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - loss: 5.9157 - mae: 0.4554 - val_loss: 5.7236 - val_mae: 0.2066 - learning_rate: 1.0000e-05
# Epoch 79/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - loss: 5.8361 - mae: 0.4317 - val_loss: 5.6565 - val_mae: 0.2101 - learning_rate: 1.0000e-05
# Epoch 80/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - loss: 5.7799 - mae: 0.4557 - val_loss: 5.5851 - val_mae: 0.1975 - learning_rate: 1.0000e-05
# Epoch 81/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - loss: 5.7137 - mae: 0.4561 - val_loss: 5.5222 - val_mae: 0.2041 - learning_rate: 1.0000e-05
# Epoch 82/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - loss: 5.6378 - mae: 0.4367 - val_loss: 5.4546 - val_mae: 0.2000 - learning_rate: 1.0000e-05
# Epoch 83/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - loss: 5.5800 - mae: 0.4500 - val_loss: 5.3901 - val_mae: 0.2043 - learning_rate: 1.0000e-05
# Epoch 84/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - loss: 5.5061 - mae: 0.4355 - val_loss: 5.3276 - val_mae: 0.2082 - learning_rate: 1.0000e-05
# Epoch 85/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - loss: 5.4409 - mae: 0.4340 - val_loss: 5.2651 - val_mae: 0.2120 - learning_rate: 1.0000e-05
# Epoch 86/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - loss: 5.3770 - mae: 0.4353 - val_loss: 5.2018 - val_mae: 0.2143 - learning_rate: 1.0000e-05
# Epoch 87/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - loss: 5.3452 - mae: 0.4844 - val_loss: 5.1381 - val_mae: 0.2043 - learning_rate: 1.0000e-05
# Epoch 88/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - loss: 5.2524 - mae: 0.4341 - val_loss: 5.0762 - val_mae: 0.2047 - learning_rate: 1.0000e-05
# Epoch 89/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - loss: 5.1995 - mae: 0.4495 - val_loss: 5.0199 - val_mae: 0.2188 - learning_rate: 1.0000e-05
# Epoch 90/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - loss: 5.1261 - mae: 0.4265 - val_loss: 4.9563 - val_mae: 0.2097 - learning_rate: 1.0000e-05
# Epoch 91/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 61s 4s/step - loss: 5.0714 - mae: 0.4338 - val_loss: 4.8962 - val_mae: 0.2092 - learning_rate: 1.0000e-05
# Epoch 92/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 72s 5s/step - loss: 5.0321 - mae: 0.4700 - val_loss: 4.8388 - val_mae: 0.2147 - learning_rate: 1.0000e-05
# Epoch 93/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 66s 4s/step - loss: 4.9362 - mae: 0.4025 - val_loss: 4.7770 - val_mae: 0.2013 - learning_rate: 1.0000e-05
# Epoch 94/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 56s 4s/step - loss: 4.8845 - mae: 0.4165 - val_loss: 4.7286 - val_mae: 0.2325 - learning_rate: 1.0000e-05
# Epoch 95/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - loss: 4.8332 - mae: 0.4282 - val_loss: 4.6690 - val_mae: 0.2211 - learning_rate: 1.0000e-05
# Epoch 96/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 4.7810 - mae: 0.4333 - val_loss: 4.6204 - val_mae: 0.2449 - learning_rate: 1.0000e-05
# Epoch 97/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 4.7432 - mae: 0.4646 - val_loss: 4.5583 - val_mae: 0.2245 - learning_rate: 1.0000e-05
# Epoch 98/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 4.6846 - mae: 0.4656 - val_loss: 4.5116 - val_mae: 0.2493 - learning_rate: 1.0000e-05
# Epoch 99/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 4.6054 - mae: 0.4201 - val_loss: 4.4530 - val_mae: 0.2364 - learning_rate: 1.0000e-05
# Epoch 100/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 4.5652 - mae: 0.4426 - val_loss: 4.3969 - val_mae: 0.2241 - learning_rate: 1.0000e-05
# Epoch 101/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 4.4907 - mae: 0.4042 - val_loss: 4.3432 - val_mae: 0.2240 - learning_rate: 1.0000e-05
# Epoch 102/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 4.4361 - mae: 0.4000 - val_loss: 4.2910 - val_mae: 0.2180 - learning_rate: 1.0000e-05
# Epoch 103/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 4.3790 - mae: 0.3910 - val_loss: 4.2359 - val_mae: 0.2085 - learning_rate: 1.0000e-05
# Epoch 104/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 4.3359 - mae: 0.4074 - val_loss: 4.1890 - val_mae: 0.2190 - learning_rate: 1.0000e-05
# Epoch 105/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 4.3304 - mae: 0.4870 - val_loss: 4.1457 - val_mae: 0.2429 - learning_rate: 1.0000e-05
# Epoch 106/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - loss: 4.2667 - mae: 0.4674 - val_loss: 4.0887 - val_mae: 0.2198 - learning_rate: 1.0000e-05
# Epoch 107/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 4.2156 - mae: 0.4602 - val_loss: 4.0487 - val_mae: 0.2385 - learning_rate: 1.0000e-05
# Epoch 108/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 4.1546 - mae: 0.4401 - val_loss: 4.0024 - val_mae: 0.2487 - learning_rate: 1.0000e-05
# Epoch 109/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 4.0907 - mae: 0.4118 - val_loss: 3.9483 - val_mae: 0.2322 - learning_rate: 1.0000e-05
# Epoch 110/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 4.0356 - mae: 0.3982 - val_loss: 3.8992 - val_mae: 0.2199 - learning_rate: 1.0000e-05
# Epoch 111/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - loss: 4.0048 - mae: 0.4297 - val_loss: 3.8534 - val_mae: 0.2239 - learning_rate: 1.0000e-05
# Epoch 112/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.9617 - mae: 0.4326 - val_loss: 3.8103 - val_mae: 0.2334 - learning_rate: 1.0000e-05
# Epoch 113/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.9046 - mae: 0.4154 - val_loss: 3.7673 - val_mae: 0.2412 - learning_rate: 1.0000e-05
# Epoch 114/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.8594 - mae: 0.4159 - val_loss: 3.7242 - val_mae: 0.2393 - learning_rate: 1.0000e-05
# Epoch 115/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.8184 - mae: 0.4209 - val_loss: 3.6751 - val_mae: 0.2270 - learning_rate: 1.0000e-05
# Epoch 116/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.7720 - mae: 0.4184 - val_loss: 3.6302 - val_mae: 0.2285 - learning_rate: 1.0000e-05
# Epoch 117/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.7330 - mae: 0.4270 - val_loss: 3.5903 - val_mae: 0.2365 - learning_rate: 1.0000e-05
# Epoch 118/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.6877 - mae: 0.4265 - val_loss: 3.5541 - val_mae: 0.2456 - learning_rate: 1.0000e-05
# Epoch 119/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.6432 - mae: 0.4232 - val_loss: 3.5061 - val_mae: 0.2365 - learning_rate: 1.0000e-05
# Epoch 120/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.5926 - mae: 0.4025 - val_loss: 3.4659 - val_mae: 0.2308 - learning_rate: 1.0000e-05
# Epoch 121/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - loss: 3.5721 - mae: 0.4446 - val_loss: 3.4325 - val_mae: 0.2512 - learning_rate: 1.0000e-05
# Epoch 122/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 3.5016 - mae: 0.3878 - val_loss: 3.3802 - val_mae: 0.2230 - learning_rate: 1.0000e-05
# Epoch 123/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - loss: 3.5044 - mae: 0.4648 - val_loss: 3.3446 - val_mae: 0.2320 - learning_rate: 1.0000e-05
# Epoch 124/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 3.4236 - mae: 0.3908 - val_loss: 3.2902 - val_mae: 0.1952 - learning_rate: 1.0000e-05
# Epoch 125/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 3.3963 - mae: 0.4118 - val_loss: 3.2566 - val_mae: 0.2134 - learning_rate: 1.0000e-05
# Epoch 126/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - loss: 3.3390 - mae: 0.3765 - val_loss: 3.2277 - val_mae: 0.2320 - learning_rate: 1.0000e-05
# Epoch 127/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 3.3025 - mae: 0.3762 - val_loss: 3.2029 - val_mae: 0.2593 - learning_rate: 1.0000e-05
# Epoch 128/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - loss: 3.2763 - mae: 0.3993 - val_loss: 3.1552 - val_mae: 0.2304 - learning_rate: 1.0000e-05
# Epoch 129/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - loss: 3.2330 - mae: 0.3861 - val_loss: 3.1370 - val_mae: 0.2734 - learning_rate: 1.0000e-05
# Epoch 130/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 62s 4s/step - loss: 3.1973 - mae: 0.3871 - val_loss: 3.1047 - val_mae: 0.2870 - learning_rate: 1.0000e-05
# Epoch 131/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 62s 4s/step - loss: 3.1661 - mae: 0.3921 - val_loss: 3.0535 - val_mae: 0.2494 - learning_rate: 1.0000e-05
# Epoch 132/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 65s 4s/step - loss: 3.1357 - mae: 0.4039 - val_loss: 3.0219 - val_mae: 0.2523 - learning_rate: 1.0000e-05
# Epoch 133/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 63s 4s/step - loss: 3.1066 - mae: 0.4150 - val_loss: 2.9802 - val_mae: 0.2360 - learning_rate: 1.0000e-05
# Epoch 134/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 68s 4s/step - loss: 3.0884 - mae: 0.4400 - val_loss: 2.9542 - val_mae: 0.2532 - learning_rate: 1.0000e-05
# Epoch 135/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 72s 4s/step - loss: 3.0200 - mae: 0.3792 - val_loss: 2.9385 - val_mae: 0.2915 - learning_rate: 1.0000e-05
# Epoch 136/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 67s 4s/step - loss: 2.9883 - mae: 0.3829 - val_loss: 2.8852 - val_mae: 0.2421 - learning_rate: 1.0000e-05
# Epoch 137/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - loss: 2.9516 - mae: 0.3768 - val_loss: 2.8506 - val_mae: 0.2347 - learning_rate: 1.0000e-05
# Epoch 138/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 72s 5s/step - loss: 2.9233 - mae: 0.3832 - val_loss: 2.8249 - val_mae: 0.2506 - learning_rate: 1.0000e-05
# Epoch 139/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 72s 5s/step - loss: 2.8903 - mae: 0.3823 - val_loss: 2.8034 - val_mae: 0.2746 - learning_rate: 1.0000e-05
# Epoch 140/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - loss: 2.8785 - mae: 0.4216 - val_loss: 2.7717 - val_mae: 0.2674 - learning_rate: 1.0000e-05
# Epoch 141/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - loss: 2.8508 - mae: 0.4258 - val_loss: 2.7298 - val_mae: 0.2511 - learning_rate: 1.0000e-05
# Epoch 142/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 64s 4s/step - loss: 2.7934 - mae: 0.3745 - val_loss: 2.7009 - val_mae: 0.2567 - learning_rate: 1.0000e-05
# Epoch 143/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - loss: 2.7896 - mae: 0.4255 - val_loss: 2.6741 - val_mae: 0.2545 - learning_rate: 1.0000e-05
# Epoch 144/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 51s 3s/step - loss: 2.7435 - mae: 0.3996 - val_loss: 2.6528 - val_mae: 0.2699 - learning_rate: 1.0000e-05
# Epoch 145/300
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 70s 4s/step - loss: 2.7143 - mae: 0.3957 - val_loss: 2.6277 - val_mae: 0.2804 - learning_rate: 1.0000e-05
# Epoch 146/300

# %%
import os
# load model and run
xmodel = tf.keras.models.load_model('nagoya_tiny_unet_120x104.keras') 

#print(xmodel.summary())

y_pred_val = xmodel.predict(X_val, verbose=1)
y_pred_test = xmodel.predict(X_test, verbose=1) 

# return values to Kelvin 
x1, x2 = dtest0.mean()['hi'], dtest0.std()['hi']
y_pred_test_r = y_pred_test*x2.values + x1.values

x1, x2 = dval0.mean()['hi'], dval0.std()['hi']
y_pred_val_r = y_pred_val*x2.values + x1.values


do = xr.Dataset( )
do['pred'] = ( ('dat', 'latitude', 'longitude'), y_pred_test_r.squeeze())  
do.coords['latitude'] = dtest0.latitude
do.coords['longitude'] = dtest0.longitude
do['real'] = dtest0['hi']

dv = xr.Dataset( )
dv['pred'] = ( ('dat', 'latitude', 'longitude'), y_pred_val_r.squeeze())  
dv.coords['latitude'] = dval0.latitude
dv.coords['longitude'] = dval0.longitude
dv['real'] = dval0['hi']

odir = 'output/'
if not os.path.exists(odir): os.makedirs(odir)
do.to_netcdf(odir+'prediction.nc')
dv.to_netcdf(odir+'validation.nc')
do.close()
dv.close()

#do.pred[0].plot()
#plt.show()
#dtest0['hi'][0].plot()
#plt.show()
#bias = do.pred - dtest0.hi.values
#bias[0].plot()
#print(bias.mean())   

print(do)
print(dv)

do['real'][1].plot()
plt.show()
do['pred'][1].plot()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# <xarray.Dataset> Size: 7MB
# Dimensions:    (dat: 44, latitude: 120, longitude: 104, date: 44)
# Coordinates:
#   * latitude   (latitude) float32 480B 34.6 34.61 34.62 ... 35.58 35.59 35.6
#   * longitude  (longitude) float32 416B 136.0 136.0 136.0 ... 137.3 137.3 137.3
#   * date       (date) datetime64[ns] 352B 2023-01-01 2023-01-07 ... 2023-12-27
# Dimensions without coordinates: dat
# Data variables:
#     pred       (dat, latitude, longitude) float32 2MB 8.761 7.123 ... 8.467
#     real       (date, latitude, longitude) float64 4MB 2.3 2.5 2.6 ... 0.3 1.0
# <xarray.Dataset> Size: 10MB
# Dimensions:    (dat: 66, latitude: 120, longitude: 104, date: 66)
# Coordinates:
#   * latitude   (latitude) float32 480B 34.6 34.61 34.62 ... 35.58 35.59 35.6
#   * longitude  (longitude) float32 416B 136.0 136.0 136.0 ... 137.3 137.3 137.3
#   * date       (date) datetime64[ns] 528B 2023-03-22 2023-09-21 ... 2023-09-22
# Dimensions without coordinates: dat
# Data variables:
#     pred       (dat, latitude, longitude) float32 3MB 16.8 16.64 ... 20.4 19.49
#     real       (date, latitude, longitude) float64 7MB 15.2 15.2 ... 21.6 22.4
